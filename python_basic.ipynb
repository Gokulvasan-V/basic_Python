# %% [markdown]
# <a href="https://colab.research.google.com/github/GokulvasanV/basic_Python/blob/main/python_basic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **conditional statements**

# %%
a= 200
b=500
if a<b:
  print("b is greater then a")
# Out:
# b is greater then a

# %%
if a>b:
  print("a is less then b")
else:
  print("b is greater then a")
# Out:
# a is greater then b

# %%
c=500
if a>b:
  print("a is less then b")
elif b==c:
  print('b equal to c')
else:
  print("b is greater then a")
# Out:
# b equal to c
