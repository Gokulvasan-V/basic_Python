# %% [markdown]
# <a href="https://colab.research.google.com/github/Gokulvasan-V/basic_Python/blob/master/Course%20Python/3_Operators_in_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **GitHub folder name : Course Python/**

# %% [markdown]
# ## **1.Intro to Python Operators**

# %% [markdown]
# **What is Expressions...?**
#
# Expressions are representations of value.

# %% [markdown]
# **What is Operator...?**
#
# An operator in a program language is a simple to perform specific Mathematical, Relational or logical operations and produce final result.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
x = 6
y = 4

print(a+b) # Expressions
print(a-b) # Expressions
print(a*b) # Expressions

# %% [markdown]
# ## 2. **Arithmetic Operators**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Addition operator
result = 5 + 3
print("Addition:", result)

# Subtraction operator
result = 8 - 2
print("Subtraction:", result)

# Multiplication operator
result = 4 * 6
print("Multiplication:", result)

# Division operator
result = 10 / 2
print("Division:", result)

# Modulus operator (returns the remainder)
result = 10 % 3
print("Modulus:", result)

# Exponentiation operator
result = 2 ** 3
print("Exponentiation:", result)

# Floor Division operator (Nearest smaller integer)
result = 428//5
result_1 = 428/5
print("Floor Division",result, f"({result_1})" )
# Out:
# Addition: 8
# Subtraction: 6
# Multiplication: 24
# Division: 5.0
# Modulus: 1
# Exponentiation: 8
# Floor Division 85 (85.6)
